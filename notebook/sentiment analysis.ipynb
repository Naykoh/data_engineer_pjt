# %% [markdown]
# ### This exercise aims to train a model to classify amazon product reviews as positive or negative

# %% [markdown]
# ### __label1__ : negative
# ### __label2__ : positive

# %%
import pandas as pd
import numpy as np
import pickle
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score

np.random.seed(500)

# %% [markdown]
# import pickle
# with open('Pickles/modeltfidvectorizer.pickle', 'rb') as data:
#     modeltfidvectorizer = pickle.load(data)

# %%
data = pd.read_csv("../data/amazon-reviews.csv",encoding='latin-1')

# %%
data.head(30)
# Out:
#                                                  text        label
# 0    Stuning even for the non-gamer: This sound tr...  __label__2
# 1    The best soundtrack ever to anything.: I'm re...  __label__2
# 2    Amazing!: This soundtrack is my favorite musi...  __label__2
# 3    Excellent Soundtrack: I truly like this sound...  __label__2
# 4    Remember, Pull Your Jaw Off The Floor After H...  __label__2
# 5    an absolute masterpiece: I am quite sure any ...  __label__2
# 6    Buyer beware: This is a self-published book, ...  __label__1
# 7    Glorious story: I loved Whisper of the wicked...  __label__2
# 8    A FIVE STAR BOOK: I just finished reading Whi...  __label__2
# 9    Whispers of the Wicked Saints: This was a eas...  __label__2
# 10   The Worst!: A complete waste of time. Typogra...  __label__1
# 11   Great book: This was a great book,I just coul...  __label__2
# 12   Great Read: I thought this book was brilliant...  __label__2
# ...

# %%
# remove blank rows, lower case and perform tokenization
data['text'] = [word_tokenize(entry.lower()) for entry in data['text'].dropna()]



# defaultdict is a dictionary that provides a default value if the index is not found
# in this example, the dictionary defaults to nouns
# tag_map = defaultdict(lambda : wn.NOUN)
# tag_map['J'] = wn.ADJ
# tag_map['V'] = wn.VERB
# tag_map['R'] = wn.ADV

stopWords = stopwords.words('english')

word_Lemmatized = WordNetLemmatizer()

for index,entry in enumerate(data['text']):
    final_words = []
    
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopWords and word.isalpha():
            final_words.append(word_Lemmatized.lemmatize(word))
    # The final processed set of words for each iteration will be stored in 'text_final'
    data.loc[index,'text_final'] = str(final_words)
# Out:
#   File "<ipython-input-32-3955554d0ed5>", line 23
#     final_words.append(word_Lemmatized.lemmatize(word]))
#                                                      ^
# SyntaxError: invalid syntax

# %%
data['text_final']
# Out:
# 0       ['stun', 'even', 'sound', 'track', 'beautiful'...
# 1       ['best', 'soundtrack', 'ever', 'anything', 're...
# 2       ['amaze', 'soundtrack', 'favorite', 'music', '...
# 3       ['excellent', 'soundtrack', 'truly', 'like', '...
# 4       ['remember', 'pull', 'jaw', 'floor', 'hear', '...
#                               ...
# 9995    ['revelation', 'life', 'small', 'town', 'ameri...
# 9996    ['great', 'biography', 'interesting', 'journal...
# 9997    ['interest', 'subject', 'poor', 'presentation'...
# 9998    ['buy', 'box', 'look', 'use', 'obviously', 'ne...
# 9999    ['beautiful', 'pen', 'fast', 'delivery', 'pen'...
# Name: text_final, Length: 10000, dtype: object

# %%
entry
# Out:
# ['beautiful',
#  'pen',
#  'and',
#  'fast',
#  'delivery',
#  '.',
#  ':',
#  'the',
#  'pen',
#  'was',
#  'shipped',
#  'promptly',
#  '.',
#  'this',
#  'is',
#  'the',
#  'classic',
#  'montblanc',
#  'pen',
#  'that',
#  'everyone',
#  'raves',
#  'about',
#  '.',
#  'it',
#  'is',
#  'black',
#  'in',
#  'color',
#  'with',
#  'golden',
#  'trim',
#  '.',
#  'it',
#  'holds',
#  'it',
#  "'s",
#  'own',
#  'and',
#  'i',
#  'am',
#  'thankful',
#  'to',
#  'my',
#  'parents',
#  'to',
#  'gift',
#  'this',
#  'to',
#  'me',
#  'as',
#  'a',
#  'graduation',
#  'present',
#  '.',
#  'someday',
#  'i',
#  'plan',
#  'on',
#  'buying',
#  'more',
#  'of',
#  'these',
#  'pens',
#  'from',
#  'amazon.the',
#  'vendors',
#  'at',
#  'amazon',
#  'are',
#  'amazing',
#  '.',
#  'i',
#  'have',
#  'been',
#  'a',
#  'long',
#  'time',
#  'shopper',
#  'at',
#  'amazon',
#  ',',
#  'mostly',
#  'pens',
#  'and',
#  'electronics',
#  '.',
#  'however',
#  'this',
#  'pen',
#  'was',
# ...

# %%
tag_map
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'J': 'a',
#              'V': 'v',
#              'R': 'r',
#              'N': 'n',
#              'M': 'n',
#              'D': 'n',
#              'I': 'n',
#              'C': 'n',
#              'S': 'n',
#              'P': 'n',
#              '$': 'n',
#              'U': 'n',
#              'E': 'n',
#              'F': 'n',
#              'W': 'n',
#              'T': 'n',
#              "'": 'n'})

# %%
data.head()
# Out:
#                                                 text        label  \
# 0  [stuning, even, for, the, non-gamer, :, this, ...  __label__2
# 1  [the, best, soundtrack, ever, to, anything, .,...  __label__2
# 2  [amazing, !, :, this, soundtrack, is, my, favo...  __label__2
# 3  [excellent, soundtrack, :, i, truly, like, thi...  __label__2
# 4  [remember, ,, pull, your, jaw, off, the, floor...  __label__2
#
#                                           text_final
# 0  ['stun', 'even', 'sound', 'track', 'beautiful'...
# 1  ['best', 'soundtrack', 'ever', 'anything', 're...
# 2  ['amaze', 'soundtrack', 'favorite', 'music', '...
# 3  ['excellent', 'soundtrack', 'truly', 'like', '...
# 4  ['remember', 'pull', 'jaw', 'floor', 'hear', '...

# %%
train_x, test_x, train_y, test_y = model_selection.train_test_split(data['text_final'],data['label'],test_size=0.3)

# %%
encoder = LabelEncoder()
train_y_encoded = encoder.fit_transform(train_y)
test_y_encoded = encoder.fit_transform(test_y)

# %%
test_x
# Out:
# 5503    ['machine', 'make', 'much', 'noise', 'power', ...
# 6376    ['less', 'substance', 'cugel', 'novel', 'come'...
# 3861    ['best', 'outting', 'go', 'disagree', 'review'...
# 1308    ['florida', 'bird', 'love', 'nature', 'guide',...
# 6380    ['good', 'remember', 'read', 'john', 'carter',...
#                               ...
# 2585    ['unbelievable', 'amaze', 'high', 'rating', 'b...
# 5065    ['expensive', 'well', 'worth', 'card', 'holder...
# 7110    ['impressive', 'greatly', 'impress', 'book', '...
# 6197    ['awesome', 'reading', 'book', 'start', 'incre...
# 4730    ['junk', 'waste', 'money', 'time', 'company', ...
# Name: text_final, Length: 3000, dtype: object

# %%
tfidf_vect = TfidfVectorizer(max_features=5000)
tfidf_vect.fit(data['text_final'])
train_x_tfidf = tfidf_vect.transform(train_x)
test_x_tfidf = tfidf_vect.transform(test_x)

# %%
with open('../models/modelvectorizer.pickle', 'wb') as output:
    pickle.dump(tfidf_vect, output)

# %%
print(tfidf_vect.vocabulary_)
# Out:
# ng': 2439, 'scissors': 3875, 'toddler': 4519, 'pin': 3287, 'bead': 374, 'sand': 3828, 'scifi': 3874, 'spiritual': 4158, 'dude': 1359, 'booklet': 481, 'il': 2216, 'tempo': 4413, 'del': 1132, 'empire': 1466, 'dire': 1224, 'mike': 2829, 'un': 4640, 'west': 4867, 'pig': 3282, 'wine': 4907, 'por': 3347, 'en': 1469, 'ella': 1444, 'excelente': 1573, 'ma': 2683, 'es': 1525, 'brian': 531, 'rust': 3806, 'manufacture': 2723, 'poem': 3325, 'verse': 4759, 'leader': 2537, 'cannon': 621, 'expedition': 1602, 'river': 3756, 'fort': 1815, 'gun': 2022, 'trek': 4588, 'cambridge': 607, 'install': 2304, 'mount': 2910, 'resonate': 3702, 'mechanical': 2778, 'core': 962, 'evident': 1559, 'traveler': 4581, 'scenery': 3862, 'odysseus': 3055, 'ulysses': 4639, 'infrared': 2283, 'vibrate': 4766, 'flashlight': 1758, 'bulb': 573, 'lennon': 2562, 'unfair': 4661, 'occasional': 3048, 'eddie': 1405, 'latin': 2520, 'funk': 1873, 'texture': 4439, 'testament': 4436, 'circumstance': 766, 'aussie': 297, 'shower': 3996, 'mon
# ...

# %%
# fit the training dataset on the NB classifier
naive = naive_bayes.MultinomialNB()
naive.fit(train_x_tfidf,train_y)
# predict the labels on validation dataset
predictions_NB = naive.predict(test_x_tfidf)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score: ",accuracy_score(predictions_NB, test_y)*100)
# Out:
# Naive Bayes Accuracy Score:  83.33333333333334

# %%
with open('../models/modelclassifier.pickle', 'wb') as output:
    pickle.dump(naive, output)

# %% [markdown]
# ### Now we should be able to provide input sentences for the model to classify

# %%
sentence_to_classify = "['love', 'incredible', 'cookie']"
sentence_to_classify = "I love this incredible cookie"
naive.predict(tfidf_vect.transform([sentence_to_classify]))[0]
# Out:
# '__label__2 '

# %%
type([sentence_to_classify])
# Out:
# list
